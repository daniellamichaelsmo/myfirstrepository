# %%
import pandas as pd
import numpy as np

# %% [markdown]
# This is importing a package.

# %%
pd.Series([10,20,30,])
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series({"a":100, "b":200, "c":300})
# Out:
# a    100
# b    200
# c    300
# dtype: int64

# %% [markdown]
# library is key as index

# %% [markdown]
# # Loading the Data

# %%
df =pd.read_csv("clinic_visits.csv")

# %%
df.head()
# Out:
#    visit_id  patient_id  age gender                     visit_date visit_type  \
# 0      1001         602   67      M  2024-01-28T00:00:00.000000000  Follow-up
# 1      1002         592   42      M  2024-03-25T00:00:00.000000000    Checkup
# 2      1003         514   41      F  2024-02-18T00:00:00.000000000  Follow-up
# 3      1004         606   30      M  2024-03-11T00:00:00.000000000    Checkup
# 4      1005         571   77      M  2024-03-21T00:00:00.000000000    Checkup
#
#    wait_time_min  billing_amount     diagnosis provider_id insurance_type  \
# 0           19.0          263.88       Healthy        P103        Private
# 1           14.0          146.21           NaN        P103       Medicare
# 2           22.0             NaN  Hypertension        P103       Medicaid
# 3            3.0          327.86      Diabetes        P103        Private
# 4            NaN          161.36  Hypertension        P101        Private
#
# ...

# %%
df.tail()
# Out:
#      visit_id  patient_id  age gender                     visit_date  \
# 295      1296         636   40      F  2024-02-15T00:00:00.000000000
# 296      1297         542   70      M  2024-01-29T00:00:00.000000000
# 297      1298         538   54      F  2024-03-02T00:00:00.000000000
# 298      1299         525   34      M  2024-03-02T00:00:00.000000000
# 299      1300         598   18      M  2024-02-26T00:00:00.000000000
#
#       visit_type  wait_time_min  billing_amount     diagnosis provider_id  \
# 295    Follow-up           46.0          161.64           Flu        P103
# 296    Follow-up           23.0             NaN        Asthma        P105
# 297  New Patient            9.0          294.74       Healthy        P105
# 298  New Patient            NaN          303.97  Hypertension        P101
# 299        Acute           40.0          109.56      Diabetes        P104
#
#     insurance_type  is_return_visit  systolic_bp  diastolic_bp  pain_score
# ...

# %%
df.shape
# Out:
# (300, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   visit_id         300 non-null    int64
#  1   patient_id       300 non-null    int64
#  2   age              300 non-null    int64
#  3   gender           300 non-null    object
#  4   visit_date       300 non-null    object
#  5   visit_type       300 non-null    object
#  6   wait_time_min    273 non-null    float64
#  7   billing_amount   278 non-null    float64
#  8   diagnosis        277 non-null    object
#  9   provider_id      300 non-null    object
#  10  insurance_type   300 non-null    object
#  11  is_return_visit  300 non-null    bool
#  12  systolic_bp      278 non-null    float64
#  13  diastolic_bp     300 non-null    int64
#  14  pain_score       274 non-null    float64
# dtypes: bool(1), float64(4), int64(4), object(6)
# memory usage: 33.2+ KB

# %%
df.dtypes
# Out:
# visit_id             int64
# patient_id           int64
# age                  int64
# gender              object
# visit_date          object
# visit_type          object
# wait_time_min      float64
# billing_amount     float64
# diagnosis           object
# provider_id         object
# insurance_type      object
# is_return_visit       bool
# systolic_bp        float64
# diastolic_bp         int64
# pain_score         float64
# dtype: object

# %%
df["visit_id"] = df["visit_id"].astype(str)
df["patient_id"] = df["patient_id"].astype(str)

# %%
df["age"].describe()
# Out:
# count    300.000000
# mean      52.606667
# std       20.859106
# min       18.000000
# 25%       34.000000
# 50%       52.000000
# 75%       72.000000
# max       89.000000
# Name: age, dtype: float64

# %%
df["visit_type"].value_counts(dropna=False)
# Out:
# visit_type
# Checkup        101
# Follow-up       86
# Acute           68
# New Patient     45
# Name: count, dtype: int64

# %%
df["diagnosis"].value_counts(dropna=False)
# Out:
# diagnosis
# Healthy         97
# Hypertension    54
# Diabetes        41
# Pneumonia       38
# Flu             24
# NaN             23
# Asthma          23
# Name: count, dtype: int64

# %%
df["insurance_type"].value_counts(dropna=False)
# Out:
# insurance_type
# Private      138
# Medicare      76
# Medicaid      70
# Uninsured     16
# Name: count, dtype: int64

# %%
df.sort_values("wait_time_min", ascending=False).head(10)
# Out:
#     visit_id patient_id  age gender                     visit_date  \
# 116     1117        595   63      F  2024-03-21T00:00:00.000000000
# 269     1270        505   64      F  2024-02-06T00:00:00.000000000
# 178     1179        615   63      F  2024-02-23T00:00:00.000000000
# 49      1050        534   36      F  2024-02-24T00:00:00.000000000
# 109     1110        514   50      F  2024-03-26T00:00:00.000000000
# 157     1158        630   86      M  2024-01-17T00:00:00.000000000
# 207     1208        612   30      F  2024-02-20T00:00:00.000000000
# 105     1106        641   60      M  2024-02-07T00:00:00.000000000
# 32      1033        550   77      F  2024-02-16T00:00:00.000000000
# 253     1254        526   75      M  2024-01-09T00:00:00.000000000
#
#       visit_type  wait_time_min  billing_amount     diagnosis provider_id  \
# 116        Acute           68.0          245.80  Hypertension        P101
# 269      Checkup           62.0          154.80      Diabetes        P103
# ...

# %%
df["diagnosis"].unique()
# Out:
# array(['Healthy', nan, 'Hypertension', 'Diabetes', 'Pneumonia', 'Flu',
#        'Asthma'], dtype=object)

# %%
df[df["wait_time_min"] > 45]
# Out:
#     visit_id patient_id  age gender                     visit_date  \
# 7       1008        621   53      M  2024-01-20T00:00:00.000000000
# 8       1009        574   62      F  2024-03-26T00:00:00.000000000
# 16      1017        501   49      F  2024-02-20T00:00:00.000000000
# 18      1019        537   68      M  2024-03-23T00:00:00.000000000
# 24      1025        548   75      F  2024-02-14T00:00:00.000000000
# 25      1026        558   75      M  2024-01-30T00:00:00.000000000
# 32      1033        550   77      F  2024-02-16T00:00:00.000000000
# 40      1041        513   72      F  2024-01-29T00:00:00.000000000
# 48      1049        507   80      F  2024-03-27T00:00:00.000000000
# 49      1050        534   36      F  2024-02-24T00:00:00.000000000
# 56      1057        553   18      M  2024-03-07T00:00:00.000000000
# 105     1106        641   60      M  2024-02-07T00:00:00.000000000
# 109     1110        514   50      F  2024-03-26T00:00:00.000000000
# ...

# %%
wait_greater_45 = df["wait_time_min"] > 45

df[wait_greater_45]
# Out:
#     visit_id patient_id  age gender                     visit_date  \
# 7       1008        621   53      M  2024-01-20T00:00:00.000000000
# 8       1009        574   62      F  2024-03-26T00:00:00.000000000
# 16      1017        501   49      F  2024-02-20T00:00:00.000000000
# 18      1019        537   68      M  2024-03-23T00:00:00.000000000
# 24      1025        548   75      F  2024-02-14T00:00:00.000000000
# 25      1026        558   75      M  2024-01-30T00:00:00.000000000
# 32      1033        550   77      F  2024-02-16T00:00:00.000000000
# 40      1041        513   72      F  2024-01-29T00:00:00.000000000
# 48      1049        507   80      F  2024-03-27T00:00:00.000000000
# 49      1050        534   36      F  2024-02-24T00:00:00.000000000
# 56      1057        553   18      M  2024-03-07T00:00:00.000000000
# 105     1106        641   60      M  2024-02-07T00:00:00.000000000
# 109     1110        514   50      F  2024-03-26T00:00:00.000000000
# ...

# %%
df[df["insurance_type"] == "Medicaid"]
# Out:
#     visit_id patient_id  age gender                     visit_date visit_type  \
# 2       1003        514   41      F  2024-02-18T00:00:00.000000000  Follow-up
# 10      1011        616   82      F  2024-03-01T00:00:00.000000000      Acute
# 14      1015        649   32      M  2024-01-13T00:00:00.000000000      Acute
# 16      1017        501   49      F  2024-02-20T00:00:00.000000000    Checkup
# 22      1023        521   79      F  2024-01-29T00:00:00.000000000  Follow-up
# ..       ...        ...  ...    ...                            ...        ...
# 280     1281        627   28      M  2024-01-13T00:00:00.000000000    Checkup
# 282     1283        524   80      F  2024-02-02T00:00:00.000000000    Checkup
# 283     1284        553   76      F  2024-01-16T00:00:00.000000000      Acute
# 291     1292        626   86      F  2024-01-13T00:00:00.000000000  Follow-up
# 296     1297        542   70      M  2024-01-29T00:00:00.000000000  Follow-up
#
# ...

# %%
df[(df["gender"] == "F") & (df["billing_amount"] >= 300)]
#filter f patients billed 300 or more $
# Out:
#     visit_id patient_id  age gender                     visit_date  \
# 22      1023        521   79      F  2024-01-29T00:00:00.000000000
# 24      1025        548   75      F  2024-02-14T00:00:00.000000000
# 43      1044        552   33      F  2024-02-01T00:00:00.000000000
# 61      1062        543   18      F  2024-02-23T00:00:00.000000000
# 70      1071        523   33      F  2024-02-15T00:00:00.000000000
# 88      1089        504   36      F  2024-02-05T00:00:00.000000000
# 114     1115        595   30      F  2024-02-28T00:00:00.000000000
# 126     1127        544   53      F  2024-01-26T00:00:00.000000000
# 130     1131        527   41      F  2024-02-06T00:00:00.000000000
# 141     1142        620   40      F  2024-01-25T00:00:00.000000000
# 150     1151        595   78      F  2024-03-31T00:00:00.000000000
# 153     1154        551   88      F  2024-02-22T00:00:00.000000000
# 156     1157        629   33      F  2024-02-14T00:00:00.000000000
# ...

# %%
df[(df["age"] >= 65) | (df["visit_type"] == "New Patient")]
# Out:
#     visit_id patient_id  age gender                     visit_date  \
# 0       1001        602   67      M  2024-01-28T00:00:00.000000000
# 4       1005        571   77      M  2024-03-21T00:00:00.000000000
# 6       1007        602   74      F  2024-02-18T00:00:00.000000000
# 10      1011        616   82      F  2024-03-01T00:00:00.000000000
# 11      1012        599   25      M  2024-02-18T00:00:00.000000000
# ..       ...        ...  ...    ...                            ...
# 291     1292        626   86      F  2024-01-13T00:00:00.000000000
# 294     1295        603   70      F  2024-02-08T00:00:00.000000000
# 296     1297        542   70      M  2024-01-29T00:00:00.000000000
# 297     1298        538   54      F  2024-03-02T00:00:00.000000000
# 298     1299        525   34      M  2024-03-02T00:00:00.000000000
#
#       visit_type  wait_time_min  billing_amount     diagnosis provider_id  \
# 0      Follow-up           19.0          263.88       Healthy        P103
# ...

# %%
df[(df["wait_time_min"] >= 40) & (df["visit_type"] == "Acute")]
# Out:
#     visit_id patient_id  age gender                     visit_date visit_type  \
# 19      1020        629   42      M  2024-03-02T00:00:00.000000000      Acute
# 24      1025        548   75      F  2024-02-14T00:00:00.000000000      Acute
# 40      1041        513   72      F  2024-01-29T00:00:00.000000000      Acute
# 49      1050        534   36      F  2024-02-24T00:00:00.000000000      Acute
# 56      1057        553   18      M  2024-03-07T00:00:00.000000000      Acute
# 100     1101        534   52      F  2024-03-27T00:00:00.000000000      Acute
# 102     1103        630   50      F  2024-01-20T00:00:00.000000000      Acute
# 104     1105        504   68      F  2024-02-06T00:00:00.000000000      Acute
# 116     1117        595   63      F  2024-03-21T00:00:00.000000000      Acute
# 143     1144        502   34      M  2024-03-27T00:00:00.000000000      Acute
# 165     1166        553   56      M  2024-03-05T00:00:00.000000000      Acute
# ...

# %%
df[(df["wait_time_min"] >= 40) & (df["visit_type"] == "Acute")] ["wait_time_min"].var()
# Out:
# np.float64(58.93589743589743)

# %% [markdown]
# .iloc is positions-based indexing by row index 0,1,2
#
# .loc is label-based indexing -- names for rows and columns

# %%
df.loc[0]
# Out:
# visit_id                                    1001
# patient_id                                   602
# age                                           67
# gender                                         M
# visit_date         2024-01-28T00:00:00.000000000
# visit_type                             Follow-up
# wait_time_min                               19.0
# billing_amount                            263.88
# diagnosis                                Healthy
# provider_id                                 P103
# insurance_type                           Private
# is_return_visit                             True
# systolic_bp                                129.0
# diastolic_bp                                  88
# pain_score                                   7.0
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# visit_id                                    1001
# patient_id                                   602
# age                                           67
# gender                                         M
# visit_date         2024-01-28T00:00:00.000000000
# visit_type                             Follow-up
# wait_time_min                               19.0
# billing_amount                            263.88
# diagnosis                                Healthy
# provider_id                                 P103
# insurance_type                           Private
# is_return_visit                             True
# systolic_bp                                129.0
# diastolic_bp                                  88
# pain_score                                   7.0
# Name: 0, dtype: object

# %%
df.iloc[0:5]
# Out:
#   visit_id patient_id  age gender                     visit_date visit_type  \
# 0     1001        602   67      M  2024-01-28T00:00:00.000000000  Follow-up
# 1     1002        592   42      M  2024-03-25T00:00:00.000000000    Checkup
# 2     1003        514   41      F  2024-02-18T00:00:00.000000000  Follow-up
# 3     1004        606   30      M  2024-03-11T00:00:00.000000000    Checkup
# 4     1005        571   77      M  2024-03-21T00:00:00.000000000    Checkup
#
#    wait_time_min  billing_amount     diagnosis provider_id insurance_type  \
# 0           19.0          263.88       Healthy        P103        Private
# 1           14.0          146.21           NaN        P103       Medicare
# 2           22.0             NaN  Hypertension        P103       Medicaid
# 3            3.0          327.86      Diabetes        P103        Private
# 4            NaN          161.36  Hypertension        P101        Private
#
#    is_return_visit  systolic_bp  diastolic_bp  pain_score
# ...

# %%
df.iloc[0:3,0:3]
# Out:
#   visit_id patient_id  age
# 0     1001        602   67
# 1     1002        592   42
# 2     1003        514   41

# %%
df.loc[0:3, "age"]
# Out:
# 0    67
# 1    42
# 2    41
# 3    30
# Name: age, dtype: int64

# %%
df.rename(columns={provider_id':'nurse_id'}, inplace=True)
                   #rename column
